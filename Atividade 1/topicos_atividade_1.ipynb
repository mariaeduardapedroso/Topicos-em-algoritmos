# %% [markdown]
# ## Código normal sem paralelismo

# %%
import time
import random

def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i-1
        while j >=0 and key < arr[j] :
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key

def analisar_ordenacao_insercao(arr):
    comparacoes = 0
    trocas = 0
    n = len(arr)
    for i in range(1, n):
        chave = arr[i]
        j = i - 1
        while j >= 0 and chave < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
            comparacoes += 1
            trocas += 1
        arr[j + 1] = chave
        comparacoes += 1
    return comparacoes, trocas

def gerar_arranjo_aleatorio(tamanho):
    return [random.randint(0, 1000) for _ in range(tamanho)]

def gerar_arranjo_ordenado(tamanho, decrescente=False):
    if decrescente:
        return [i for i in range(tamanho, 0, -1)]
    else:
        return [i for i in range(1, tamanho + 1)]

def executar_experimento():
    tamanhos = [5000, 10000, 15000, 20000, 25000, 30000]
    casos = ['melhor', 'medio', 'pior']
    resultados = {}
    for caso in casos:
        resultados[caso] = {}
        for tamanho in tamanhos:
            resultados[caso][tamanho] = []
            for _ in range(10):
                if caso == 'melhor':
                    arr = gerar_arranjo_ordenado(tamanho)
                elif caso == 'medio':
                    arr = gerar_arranjo_aleatorio(tamanho)
                elif caso == 'pior':
                    arr = gerar_arranjo_ordenado(tamanho, decrescente=True)
                tempo_inicio = time.time()
                insertion_sort(arr)
                tempo_fim = time.time()
                tempo_execucao = tempo_fim - tempo_inicio
                resultados[caso][tamanho].append(tempo_execucao)
                print(f"Tamanho: {tamanho}, Caso {caso} Tempo médio de execução: {tempo_execucao} s")
    return resultados

def tempo_execucao_medio(resultados):
    medias = {}
    for caso, tamanhos in resultados.items():
        medias[caso] = {}
        for tamanho, tempos in tamanhos.items():
            medias[caso][tamanho] = sum(tempos) / len(tempos)
    return medias

def plotar_resultados(medias):
    import matplotlib.pyplot as plt
    tamanhos = [5000, 10000, 15000, 20000, 25000, 30000]
    for caso, dados in medias.items():
        plt.plot(tamanhos, [dados[tamanho] for tamanho in tamanhos], label=caso)
    plt.xlabel('Tamanho do Vetor')
    plt.ylabel('Tempo Médio de Execução (s)')
    plt.title('Desempenho da Ordenação por Inserção')
    plt.legend()
    plt.show()

def principal():
    resultados = executar_experimento()
    medias = tempo_execucao_medio(resultados)
    print("Resultados do experimento:")
    for caso, data in medias.items():
        print(f"Caso: {caso}")
        for tamanho, tempo in data.items():
            print(f"Tamanho: {tamanho}, Tempo médio de execução: {tempo:.6f} s")
    plotar_resultados(medias)

if __name__ == "__main__":
    principal()
# Out:
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.001958608627319336 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.002248525619506836 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.0021674633026123047 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.0021915435791015625 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.002184629440307617 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.0021855831146240234 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.002129793167114258 s
# Tamanho: 30000, Caso pior Tempo médio de execução: 91.66267085075378 s
# Tamanho: 30000, Caso pior Tempo médio de execução: 94.07029390335083 s
# Tamanho: 30000, Caso pior Tempo médio de execução: 91.97608542442322 s
# Tamanho: 30000, Caso pior Tempo médio de execução: 94.30701398849487 s
# Tamanho: 30000, Caso pior Tempo médio de execução: 100.84810328483582 s
# Tamanho: 30000, Caso pior Tempo médio de execução: 104.12623596191406 s
# Tamanho: 30000, Caso pior Tempo médio de execução: 108.77789044380188 s
# Resultados do experimento:
# Caso: melhor
# Tamanho: 5000, Tempo médio de execução: 0.002148 s
# Tamanho: 10000, Tempo médio de execução: 0.004379 s
# Tamanho: 15000, Tempo médio de execução: 0.006755 s
# Tamanho: 20000, Tempo médio de execução: 0.009584 s
# Tamanho: 25000, Tempo médio de execução: 0.011498 s
# Tamanho: 30000, Tempo médio de execução: 0.013540 s
# Caso: medio
# Tamanho: 5000, Tempo médio de execução: 1.332231 s
# Tamanho: 10000, Tempo médio de execução: 5.284345 s
# Tamanho: 15000, Tempo médio de execução: 11.811456 s
# Tamanho: 20000, Tempo médio de execução: 20.828074 s
# Tamanho: 25000, Tempo médio de execução: 32.265533 s
# Tamanho: 30000, Tempo médio de execução: 46.916389 s
# Caso: pior
# Tamanho: 5000, Tempo médio de execução: 2.497465 s
# Tamanho: 10000, Tempo médio de execução: 10.072714 s
# Tamanho: 15000, Tempo médio de execução: 22.777529 s
# Tamanho: 20000, Tempo médio de execução: 40.659020 s
# Tamanho: 25000, Tempo médio de execução: 64.303906 s
# Tamanho: 30000, Tempo médio de execução: 96.338735 s

# %% [markdown]
# ### Código pronto com arquivo sem paralelismo

# %%
import time
import random
import matplotlib.pyplot as plt
tamanhos = [5000, 10000, 15000, 20000, 25000, 30000]

def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i-1
        while j >=0 and key < arr[j] :
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key

def analisar_ordenacao_insercao(arr):
    comparacoes = 0
    trocas = 0
    n = len(arr)
    for i in range(1, n):
        chave = arr[i]
        j = i - 1
        while j >= 0 and chave < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
            comparacoes += 1
            trocas += 1
        arr[j + 1] = chave
        comparacoes += 1
    return comparacoes, trocas

def gerar_arranjo_aleatorio(tamanho):
    return [random.randint(0, 1000) for _ in range(tamanho)]

def gerar_arranjo_ordenado(tamanho, decrescente=False):
    if decrescente:
        return [i for i in range(tamanho, 0, -1)]
    else:
        return [i for i in range(1, tamanho + 1)]

def executar_experimento():
    casos = ['melhor', 'medio', 'pior']
    resultados = {}
    for caso in casos:
        resultados[caso] = {}
        for tamanho in tamanhos:
            resultados[caso][tamanho] = []
            with open('execussao.txt', 'a+') as f:
              for _ in range(10):
                  if caso == 'melhor':
                      arr = gerar_arranjo_ordenado(tamanho)
                  elif caso == 'medio':
                      arr = gerar_arranjo_aleatorio(tamanho)
                  elif caso == 'pior':
                      arr = gerar_arranjo_ordenado(tamanho, decrescente=True)
                  tempo_inicio = time.time()
                  insertion_sort(arr)
                  tempo_fim = time.time()
                  tempo_execucao = tempo_fim - tempo_inicio
                  resultados[caso][tamanho].append(tempo_execucao)
                  print(f"Tamanho: {tamanho}, Caso {caso} Tempo médio de execução: {tempo_execucao} s")
                  f.write(f"Tamanho: {tamanho}, Caso {caso} Tempo medio de execucao: {tempo_execucao} s\n")
    return resultados

def tempo_execucao_medio(resultados):
    medias = {}
    for caso, tamanhos in resultados.items():
        medias[caso] = {}
        for tamanho, tempos in tamanhos.items():
            medias[caso][tamanho] = sum(tempos) / len(tempos)
    return medias

def plotar_resultado(caso, dados):
    plt.plot(tamanhos, [dados[tamanho] for tamanho in tamanhos], label=caso)
    plt.xlabel('Tamanho do Vetor')
    plt.ylabel('Tempo Médio de Execução (s)')
    plt.title(f'Desempenho da Ordenação por Inserção - Caso {caso.capitalize()}')
    plt.legend()
    plt.show()

def plotar_resultados(medias):
    for caso, dados in medias.items():
        plt.plot(tamanhos, [dados[tamanho] for tamanho in tamanhos], label=caso)
    plt.xlabel('Tamanho do Vetor')
    plt.ylabel('Tempo Médio de Execução (s)')
    plt.title('Desempenho da Ordenação por Inserção')
    plt.legend()
    plt.show()

def principal():
    resultados = executar_experimento()
    medias = tempo_execucao_medio(resultados)
    with open('output.txt', 'w') as f:
        f.write("Resultados do experimento:\n")
        for caso, data in medias.items():
            f.write(f"Caso: {caso}\n")
            for tamanho, tempo in data.items():
                f.write(f"Tamanho: {tamanho}, Tempo medio de execucao: {tempo:.6f} s\n")
    for caso, dados in medias.items():
        plotar_resultado(caso, dados)
    plotar_resultados(medias)

if __name__ == "__main__":
    principal()

# %% [markdown]
# ## Codigo normal com paralelismo

# %%
import time
import random

def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i-1
        while j >=0 and key < arr[j] :
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key

def analisar_ordenacao_insercao(arr):
    comparacoes = 0
    trocas = 0
    n = len(arr)
    for i in range(1, n):
        chave = arr[i]
        j = i - 1
        while j >= 0 and chave < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
            comparacoes += 1
            trocas += 1
        arr[j + 1] = chave
        comparacoes += 1
    return comparacoes, trocas

def gerar_arranjo_aleatorio(tamanho):
    return [random.randint(0, 1000) for _ in range(tamanho)]

def gerar_arranjo_ordenado(tamanho, decrescente=False):
    if decrescente:
        return [i for i in range(tamanho, 0, -1)]
    else:
        return [i for i in range(1, tamanho + 1)]

def executar_experimento():
    tamanhos = [5000, 10000, 15000, 20000, 25000, 30000]
    casos = ['melhor', 'medio', 'pior']
    resultados = {}
    for caso in casos:
        resultados[caso] = {}
        for tamanho in tamanhos:
            resultados[caso][tamanho] = []
            for _ in range(10):
                if caso == 'melhor':
                    arr = gerar_arranjo_ordenado(tamanho)
                elif caso == 'medio':
                    arr = gerar_arranjo_aleatorio(tamanho)
                elif caso == 'pior':
                    arr = gerar_arranjo_ordenado(tamanho, decrescente=True)
                tempo_inicio = time.time()
                insertion_sort(arr)
                tempo_fim = time.time()
                tempo_execucao = tempo_fim - tempo_inicio
                resultados[caso][tamanho].append(tempo_execucao)
                print(f"Tamanho: {tamanho}, Caso {caso} Tempo médio de execução: {tempo_execucao} s")
    return resultados

def tempo_execucao_medio(resultados):
    medias = {}
    for caso, tamanhos in resultados.items():
        medias[caso] = {}
        for tamanho, tempos in tamanhos.items():
            medias[caso][tamanho] = sum(tempos) / len(tempos)
    return medias

def plotar_resultados(medias):
    import matplotlib.pyplot as plt
    tamanhos = [5000, 10000, 15000, 20000, 25000, 30000]
    for caso, dados in medias.items():
        plt.plot(tamanhos, [dados[tamanho] for tamanho in tamanhos], label=caso)
    plt.xlabel('Tamanho do Vetor')
    plt.ylabel('Tempo Médio de Execução (s)')
    plt.title('Desempenho da Ordenação por Inserção')
    plt.legend()
    plt.show()

def principal():
    resultados = executar_experimento()
    medias = tempo_execucao_medio(resultados)
    print("Resultados do experimento:")
    for caso, data in medias.items():
        print(f"Caso: {caso}")
        for tamanho, tempo in data.items():
            print(f"Tamanho: {tamanho}, Tempo médio de execução: {tempo:.6f} s")
    plotar_resultados(medias)

if __name__ == "__main__":
    principal()
# Out:
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.013954877853393555 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.0030121803283691406 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.0018889904022216797 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.001575469970703125 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.01107931137084961 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.009764432907104492 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.01039886474609375 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.007109403610229492 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.007816791534423828 s
# Tamanho: 5000, Caso melhor Tempo médio de execução: 0.017586946487426758 s
# Tamanho: 10000, Caso melhor Tempo médio de execução: 0.02889871597290039 s
# Tamanho: 10000, Caso melhor Tempo médio de execução: 0.01785445213317871 s
# Tamanho: 10000, Caso melhor Tempo médio de execução: 0.013360023498535156 s
# Tamanho: 10000, Caso melhor Tempo médio de execução: 0.022554397583007812 s
# Tamanho: 10000, Caso melhor Tempo médio de execução: 0.016614675521850586 s
# Tamanho: 10000, Caso melhor Tempo médio de execução: 0.018062353134155273 s
# Tamanho: 10000, Caso melhor Tempo médio de execução: 0.016857147216796875 s
# Tamanho: 10000, Caso melhor Tempo médio de execução: 0.01633930206298828 s
# Tamanho: 10000, Caso melhor Tempo médio de execução: 0.030306100845336914 s
# Tamanho: 10000, Caso melhor Tempo médio de execução: 0.016972064971923828 s
# Tamanho: 15000, Caso melhor Tempo médio de execução: 0.028025150299072266 s
# Tamanho: 15000, Caso melhor Tempo médio de execução: 0.016269207000732422 s
# Tamanho: 15000, Caso melhor Tempo médio de execução: 0.018075227737426758 s
# Tamanho: 15000, Caso melhor Tempo médio de execução: 0.03765368461608887 s
# Tamanho: 15000, Caso melhor Tempo médio de execução: 0.03073263168334961 s
# Tamanho: 15000, Caso melhor Tempo médio de execução: 0.0250394344329834 s
# Tamanho: 25000, Tempo médio de execução: 64.851438 s
# Tamanho: 30000, Tempo médio de execução: 91.814672 s

# %% [markdown]
# ### Código Paralelismo Pronto com Arquivo

# %%
import time
import random
import matplotlib.pyplot as plt
from multiprocessing import Pool
tamanhos = [5000, 10000, 15000, 20000, 25000, 30000]

def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i-1
        while j >=0 and key < arr[j] :
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key

def gerar_arranjo_aleatorio(tamanho):
    return [random.randint(0, 1000) for _ in range(tamanho)]

def gerar_arranjo_ordenado(tamanho, decrescente=False):
    if decrescente:
        return [i for i in range(tamanho, 0, -1)]
    else:
        return [i for i in range(1, tamanho + 1)]

def executar_experimento(caso_tamanho):
    caso, tamanho = caso_tamanho
    tempos = []
    with open('execussao.txt', 'a+') as f:
        for _ in range(10):
            if caso == 'melhor':
                arr = gerar_arranjo_ordenado(tamanho)
            elif caso == 'medio':
                arr = gerar_arranjo_aleatorio(tamanho)
            elif caso == 'pior':
                arr = gerar_arranjo_ordenado(tamanho, decrescente=True)
            tempo_inicio = time.time()
            insertion_sort(arr)
            tempo_fim = time.time()
            tempo_execucao = tempo_fim - tempo_inicio
            tempos.append(tempo_execucao)
            print(f"Tamanho: {tamanho}, Caso {caso} Tempo médio de execução: {tempo_execucao} s")
            f.write(f"Tamanho: {tamanho}, Caso {caso} Tempo medio de execucao: {tempo_execucao} s\n")
    return caso, tamanho, sum(tempos) / len(tempos)

def tempo_execucao_medio(resultados):
    medias = {}
    for caso, tamanhos in resultados.items():
        medias[caso] = {}
        for tamanho, tempos in tamanhos.items():
            medias[caso][tamanho] = sum(tempos) / len(tempos)
    return medias

def plotar_resultado(caso, dados):
    plt.plot(tamanhos, [dados[tamanho] for tamanho in tamanhos], label=caso)
    plt.xlabel('Tamanho do Vetor')
    plt.ylabel('Tempo Médio de Execução (s)')
    plt.title(f'Desempenho da Ordenação por Inserção - Caso {caso.capitalize()}')
    plt.legend()
    plt.show()

def plotar_resultados(medias):
    for caso, dados in medias.items():
        plt.plot(tamanhos, [dados[tamanho] for tamanho in tamanhos], label=caso)
    plt.xlabel('Tamanho do Vetor')
    plt.ylabel('Tempo Médio de Execução (s)')
    plt.title('Desempenho da Ordenação por Inserção')
    plt.legend()
    plt.show()

def principal():
    casos = ['melhor', 'medio', 'pior']
    pool = Pool()
    resultados = {}
    for caso in casos:
        resultados[caso] = {}
        resultados_temp = pool.map(executar_experimento, [(caso, tamanho) for tamanho in tamanhos])
        for r in resultados_temp:
            resultados[r[0]][r[1]] = [r[2]]  # Guardar apenas o tempo médio de execução
    with open('output.txt', 'w') as f:
        f.write("Resultados do experimento:\n")
        for caso, data in tempo_execucao_medio(resultados).items():
            f.write(f"Caso: {caso}\n")
            for tamanho, tempo in data.items():
                f.write(f"Tamanho: {tamanho}, Tempo medio de execucao: {tempo:.6f} s\n")
    for caso, dados in tempo_execucao_medio(resultados).items():
        plotar_resultado(caso, dados)
    plotar_resultados(tempo_execucao_medio(resultados))

if __name__ == "__main__":
    principal()
